# %%
# %cd /content/drive/MyDrive/nlp
# Out:
# /content/drive/MyDrive/nlp

# %%
from collections import defaultdict as dd
import numpy as np

# %%
bigrams = dd(lambda : dd(int))
r_bigrams = dd(lambda : dd(int))
file = open('2grams.txt', 'r')

for e in file:
    if e[-1] == '\n':
        e = e[:-1]
    e = e.lower()
    l, first, second = e.split(' ')
    bigrams[first][second] += int(l)
    r_bigrams[second][first] += int(l)
    if int(l) <= 1:
        break

file.close()
sum_of_bigrams = 0
for e in bigrams:
    for f in bigrams[e]:
        sum_of_bigrams += bigrams[e][f]

file = open('unigrams.txt', 'r')
unigrams = dict()
for e in file:
    if e[-1] == '\n':
        e = e[:-1]
    e = e.lower()
    first, second = e.split(' ')
    unigrams[first] = int(second)

file.close()
sum_of_unigrams = sum(unigrams[e] for e in unigrams)

# %%
file = open('supertags.txt', 'r')
tags = dict()
for i in file:
    e, f = i.split(' ')
    e = e.lower()
    if f[-1] == '\n':
        f = f[:-1]
    tags[e] = f

file.close()

def tag(s):
    if s in tags:
        return tags[s]
    else:
        return ('^' + s)[-3:]


tbigrams = dd(lambda : dd(int))
tunigrams = dd(int)
for e in bigrams:
    for f in bigrams[e]:
        tbigrams[tag(e)][tag(f)] += bigrams[e][f]
for e in unigrams:
    tunigrams[tag(e)] += unigrams[e]

# %%
print(sum_of_bigrams)
print(sum_of_unigrams)
# Out:
# 434398049
# 451846640

# %% [markdown]
# $$PMI(w_1,w_2) = \log\frac{P(w_1,w_2)}{P(w_1)\cdot P(w_2)}$$
# $$PPMI(w_1, w_2) = \max(PMI(w_1,w_2), 0)$$

# %%
def P_big(w1, w2):
    return np.log(bigrams[w1][w2]/sum_of_bigrams + 1e-10)

def P_uni(w1):
    return np.log(unigrams[w1]/sum_of_unigrams + 1e-10)

def PMI(w1,w2):
    return P_big(w1, w2) - (P_uni(w1) + P_uni(w2))

# %%
def PPMI(w1, w2):
    return max(PMI(w1,w2), 0)

# %% [markdown]
# $$PSM(w_1,w_2) = f(w_1,w_2) \cdot \left(\log f(w_1,w_2) - \log \frac{f(w_1)\cdot f(w_2)}{\sum_i f(w_i)} - 1 \right)$$
# gdzie $f$ to statystyki bigramowe/unigramowe.

# %%
def PSM(w1, w2):
    def f0(w1, w2):
        return unigrams[w1]*unigrams[w2]/sum_of_unigrams
    f = bigrams[w1][w2]
    return f * (np.log(f + 1e-10) - np.log(f0(w1,w2) + 1e-10) - 1 )

# %% [markdown]
# $$tagPMI = PMI(w_1,w_2) + PMI(t_1,t_2)$$
# gdzie $t_1, t_2$ to tagi słów $w_1,w_2$.

# %%
def P_big_t(t1, t2):
    return np.log(tbigrams[t1][t2]/sum_of_bigrams + 1e-10)

def P_uni_t(t1):
    return np.log(tunigrams[t1]/sum_of_unigrams + 1e-10)

def PMI_t(w1,w2):
    t1 = tag(w1)
    t2 = tag(w2)
    return P_big_t(t1, t2) - (P_uni_t(t1) + P_uni_t(t2))


def PMI_WandT(w1, w2):
    return PMI(w1,w2) + PMI_t(w1,w2)

# %%
def top_k(w, f, k):
    bests = [(0, '')] * k
    for e in bigrams[w]:
        n = f(w,e)
        if n >= bests[k-1][0]:
            bests = [(n, e)] + bests[:-1]
            bests.sort(key=lambda x: x[0], reverse=True)
    bestsr = [(0, '')] * k
    for e in r_bigrams[w]:
        if e == '<bos>':
            continue
        n = f(e,w)
        if n >= bestsr[k-1][0]:
            bestsr = [(n, e)] + bestsr[:-1]
            bestsr.sort(key=lambda x: x[0], reverse=True)
        
    return bests, bestsr

# %%
word = 'pies'
print(word)
print('{:^70} {:^70} {:^80}'.format('PPMI', 'PSM', 'tPMI'))
print('{:40} {:40} {:40} {:40} {:40} {:30}'.format('Następniki', 'Poprzedniki', 'Następniki', 'Poprzedniki', 'Następniki', 'Poprzedniki'))
e1, f1 = top_k(word, PPMI, 10)
e2, f2 = top_k(word, PSM, 10)
e3, f3 = top_k(word, PMI_WandT, 10)
for i in range(len(e)):
    print('{:03.5f} {:30} {:03.5f} {:30} {:03.5f} {:30} {:03.5f} {:30} {:03.5f} {:30} {:03.5f} {}'.format(
            e1[i][0], e1[i][1], f1[i][0], f1[i][1], e2[i][0], e2[i][1], f2[i][0], f2[i][1], e3[i][0], e3[i][1], f3[i][0], f3[i][1]))
# Out:
# pies
#                                  PPMI                                                                   PSM                                                                         tPMI
# Następniki                               Poprzedniki                              Następniki                               Poprzedniki                              Następniki                               Poprzedniki
# 11.30188 descalzos                      11.30124 bernenski                      668.53500 pogrzebany                     511.48712 mój                            15.93337 descalzos                      12.65893 dorosły
# 11.30124 stróżująco-obronny             11.30124 oczipowany                     443.57206 pasterski                      486.56526 twój                           13.67837 chodzki                        12.39362 berneński
# 11.08076 chodzki                        11.08076 ujadający                      374.18877 myśliwski                      318.93681 jak                            13.56940 miluś                          12.37087 jamnikowaty
# 10.90317 zaganiający                    10.64195 berneński                      293.08464 rasy                           220.13643 że                             13.26552 powiedziaa                     12.26297 trzygłowy
# 10.51802 stróżujący                     10.61920 jamnikowaty                    246.42197 stróżujący                     216.66387 jako                           12.57039 dowodny                        12.13928 bezpański
# 10.46274 powiedziaa                     10.61582 trzygłowy                      207.61735 ma                             198.87645 każdy                          12.49066 przebrzydły                    11.42995 ujadający
# 10.36272 asystujący                     10.38761 bezpański                      200.59060 jest                           186.71209 nasz                           12.34607 zaganiający                    11.15281 mj
# 10.29720 dowodny                        10.21747 lowiectwo                      175.06674 ogrodnika                      178.82154 to                             12.26133 zaprzęgowy                     10.80199 uroczy
# 10.21747 przebrzydły                    9.93166 zaszczekał                     149.14783 asystujący                     175.20904 gdy                            12.18465 pasterski                      10.72173 antropomorficzny
# 10.05440 huckleberry                    9.77281 wygłodniały                    129.59741 może                           153.62119 berneński                      11.96092 stróżujący                     10.67928 wygłodniały

# %%
word = 'kot'
print(word)
print('{:^70} {:^70} {:^80}'.format('PPMI', 'PSM', 'tPMI'))
print('{:40} {:40} {:40} {:40} {:40} {:30}'.format('Następniki', 'Poprzedniki', 'Następniki', 'Poprzedniki', 'Następniki', 'Poprzedniki'))
e1, f1 = top_k(word, PPMI, 10)
e2, f2 = top_k(word, PSM, 10)
e3, f3 = top_k(word, PMI_WandT, 10)
for i in range(len(e)):
    print('{:.5f} {:30} {:.5f} {:30} {:.5f} {:30} {:.5f} {:30} {:.5f} {:30} {:.5f} {}'.format(
            e1[i][0], e1[i][1], f1[i][0], f1[i][1], e2[i][0], e2[i][1], f2[i][0], f2[i][1], e3[i][0], e3[i][1], f3[i][0], f3[i][1]))
# Out:
# kot
#                                  PPMI                                                                   PSM                                                                         tPMI
# Następniki                               Poprzedniki                              Następniki                               Poprzedniki                              Następniki                               Poprzedniki
# 11.84886 naplakal                       11.84928 tirin                          524.04692 napłakał                       1177.85359 maciej                         15.54564 meowth                         15.03463 tirin
# 11.73427 napłakał                       11.16682 gadajacy                       170.34014 pospolity                      571.31415 czarny                         14.78221 czarnołapy                     14.35379 jewhenij
# 11.45079 burmański                      10.76509 jewhenij                       123.71421 domowy                         343.19768 rasy                           14.76002 owni                           13.08451 gadajacy
# 11.16682 czarnołapy                     10.35118 gadający                       114.87925 leopold                        239.49384 mój                            14.75570 naplakal                       11.00839 puchaty
# 11.16682 owni                           9.47126 puchaty                        90.93873 syberyjski                     190.06649 twój                           14.66270 mruczysław                     10.86980 dziki
# 11.16174 mruczysław                     9.26684 głody                          73.93865 ma                             189.10892 tomasz                         14.55147 behemot                        10.77638 gadający
# 10.94592 kuler                          8.55620 napłakał                       61.33167 rosyjski                       148.51643 jak                            13.82980 napłakał                       10.57840 głody
# 10.76509 meowth                         8.20706 wypasiony                      57.24160 (                              135.32226 stanisław                      13.53259 spaślak                        10.45346 dorosły
# 10.47928 killay                         7.99953 tańczący                       51.24999 filemon                        123.73605 jakub                          13.50526 prot                           9.84914 napłakał
# 10.47928 spaślak                        7.90996 chytry                         47.98162 prot                           80.76126 nasz                           13.23612 filemon                        9.66090 38.

# %%
word = 'chłopiec'
print(word)
print('{:^70} {:^70} {:^80}'.format('PPMI', 'PSM', 'tPMI'))
print('{:40} {:40} {:40} {:40} {:40} {:30}'.format('Następniki', 'Poprzedniki', 'Następniki', 'Poprzedniki', 'Następniki', 'Poprzedniki'))
e1, f1 = top_k(word, PPMI, 10)
e2, f2 = top_k(word, PSM, 10)
e3, f3 = top_k(word, PMI_WandT, 10)
for i in range(len(e)):
    print('{:.5f} {:30} {:.5f} {:30} {:.5f} {:30} {:.5f} {:30} {:.5f} {:30} {:.5f} {}'.format(
            e1[i][0], e1[i][1], f1[i][0], f1[i][1], e2[i][0], e2[i][1], f2[i][0], f2[i][1], e3[i][0], e3[i][1], f3[i][0], f3[i][1]))
# Out:
# chłopiec
#                                  PPMI                                                                   PSM                                                                         tPMI
# Następniki                               Poprzedniki                              Następniki                               Poprzedniki                              Następniki                               Poprzedniki
# 10.90248 obierający                     11.80542 bestia-zielony                 178.10998 miał                           902.07326 mały                           12.12077 obierający                     13.23603 11-letni
# 10.21382 popatrzał                      10.71703 anaruk                         147.87197 został                         785.42789 młody                          11.35954 popatrzał                      13.02770 14-letni
# 9.61860 zapalający                     10.42265 trzynastoletni                 132.95439 był                            415.31829 jako                           10.83689 zapalający                     13.02101 13-letni
# 9.36263 zafascynuje                    10.23071 czternastoletni                121.15193 okrętowy                       177.74885 kilkunastoletni                10.62289 okrętowy                       12.88423 8-letni
# 9.33123 urzeknie                       10.10504 11-letni                       119.23577 zaczął                         177.70122 gdy                            10.51037 kabinowy                       12.81247 12-letni
# 9.11885 okrętowy                       10.01850 jedenastoletni                 60.24513 wstąpił                        168.12107 dziesięcioletni                10.50742 zafascynuje                    12.80667 9-letni
# 9.02652 ugryziony                      9.92864 kilkunastoletni                60.11396 zostaje                        155.51999 12-letni                       10.47602 urzeknie                       12.63034 16-letni
# 9.00634 kabinowy                       9.89671 14-letni                       59.68976 imieniem                       146.02538 letni                          10.17384 stajenny                       12.27680 7-letni
# 8.77541 czternastoletni                9.89002 13-letni                       56.21864 trafił                         125.78990 że                             9.82628 bawiący                        12.13729 15-letni
# 8.66980 stajenny                       9.75324 8-letni                        51.86800 poznaje                        119.45339 czternastoletni                9.68347 tip                            11.92533 trzynastoletni

# %%
word = 'dziewczynka'
print(word)
print('{:^70} {:^70} {:^80}'.format('PPMI', 'PSM', 'tPMI'))
print('{:40} {:40} {:40} {:40} {:40} {:30}'.format('Następniki', 'Poprzedniki', 'Następniki', 'Poprzedniki', 'Następniki', 'Poprzedniki'))
e1, f1 = top_k(word, PPMI, 10)
e2, f2 = top_k(word, PSM, 10)
e3, f3 = top_k(word, PMI_WandT, 10)
for i in range(len(e)):
    print('{:03.5f} {:30} {:03.5f} {:30} {:03.5f} {:30} {:03.5f} {:30} {:03.5f} {:30} {:03.5f} {}'.format(
            e1[i][0], e1[i][1], f1[i][0], f1[i][1], e2[i][0], e2[i][1], f2[i][0], f2[i][1], e3[i][0], e3[i][1], f3[i][0], f3[i][1]))
# Out:
# dziewczynka
#                                  PPMI                                                                   PSM                                                                         tPMI
# Następniki                               Poprzedniki                              Następniki                               Poprzedniki                              Następniki                               Poprzedniki
# 11.48803 zzieleniała                    12.17007 3,5-letnia                     101.17083 miała                          1433.50826 mała                           13.87168 bojąca                         13.47863 dwunastoletnia
# 10.97682 bojąca                         11.77200 1,5-roczna                     93.71574 została                        173.55058 letnia                         13.18215 zzieleniała                    13.26526 ośmioletnia
# 9.72728 zafascynuje                    10.56720 7-letnia                       77.75784 zmarła                         131.37312 kilkuletnia                    12.41156 uczęszczająca                  12.97938 kilkunastoletnia
# 9.62573 zeskoczyła                     10.51704 dwunastoletnia                 72.92575 ma                             96.92054 czteroletnia                   12.25273 wstępująca                     12.89084 dziewięcioletnia
# 9.51671 uczęszczająca                  10.42016 9-letnia                       70.42396 imieniem                       89.21381 każda                          12.10953 jedenastoletnia                12.81545 czteroletnia
# 9.37099 osiemnastolatka                10.31536 12-letnia                      67.81525 ucieka                         82.67087 10-letnia                      11.47858 zeskoczyła                     12.76177 kilkuletnia
# 9.35787 wstępująca                     10.30367 ośmioletnia                    60.80867 była                           75.78667 dwunastoletnia                 11.35380 zachwycała                     12.74763 jasnowłosa
# 9.22084 pasjonowała                    10.22911 10-letnia                      54.07072 otrzymała                      74.07808 ośmioletnia                    11.32110 wkładała                       12.70202 sześcioletnia
# 9.20359 zachwycała                     10.19917 11-letnia                      53.21111 wypadła                        72.10315 że                             11.07068 pasjonowała                    12.69999 jedenastoletnia
# 9.17089 wkładała                       10.05027 13-letnia                      52.82996 zostaje                        71.63841 ta                             10.27651 zafascynuje                    12.68384 1,5-roczna
